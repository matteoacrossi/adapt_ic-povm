# %% [markdown]
# # List of Hamiltonians considered
#
# The Hamiltonians are stored in the file `hamiltonians.pickle`. The file is generated with `prepare_chemistry_hamiltonians.py`.

# %%
import pandas as pd
df = pd.DataFrame(pd.read_pickle('hamiltonians.pickle'))

# %% [markdown]
# The file is a list of dictionaries. Each element contains the following information:

# %%
pd.read_pickle('hamiltonians.pickle')[0]
# Out:
# {'molecule': 'H2',
#  'basis': 'sto3g',
#  'two_qubit_reduction': False,
#  'z2symmetry_reduction': False,
#  'freeze_core': False,
#  'mapping': 'parity',
#  'operator': <qiskit.aqua.operators.legacy.weighted_pauli_operator.WeightedPauliOperator at 0x2af6e02ead60>,
#  'qubits': 4,
#  'num_paulis': 15,
#  'vqe_circuit': <qiskit.circuit.library.n_local.real_amplitudes.RealAmplitudes at 0x2af7eb2c9b80>,
#  'vqe_value': -1.842665192696192,
#  'exact_circuit': <qiskit.circuit.quantumcircuit.QuantumCircuit at 0x2af7eb317f10>,
#  'exact_value': -1.842686681905733,
#  'name': '4q H2 parity'}

# %% [markdown]
# This is the full list of Hamiltonians:

# %%
df.drop(columns=['vqe_circuit', 'exact_circuit', 'operator',])
# Out:
#    molecule  basis  two_qubit_reduction  z2symmetry_reduction  freeze_core  \
# 0        H2  sto3g                False                 False        False
# 1        H2  sto3g                False                 False        False
# 2        H2   631g                 True                 False        False
# 3        H2   631g                False                 False        False
# 4        H2   631g                False                 False        False
# 5        H2  sto3g                False                 False        False
# 6        H2   631g                False                 False        False
# 7       LiH  sto3g                 True                  True        False
# 8       LiH  sto3g                 True                  True         True
# 9       LiH  sto3g                 True                 False        False
# 10      LiH  sto3g                False                  True         True
# 11      LiH  sto3g                False                  True        False
# 12      H2O  sto3g                False                  True         True
# 13      H2O  sto3g                False                  True        False
# 14      H2O  sto3g                False                  True        False
# 15      H2O  sto3g                False                  True         True
# 16      H2O  sto3g                False                 False         True
# 17      LiH  sto3g                False                 False        False
# 18       H2  sto3g                False                 False        False
# 19       H2   631g                False                 False        False
# 20      LiH  sto3g                False                 False        False
# 21      H2O  sto3g                False                 False         True
# 22      H2O  sto3g                False                 False         True
# 23      LiH  sto3g                False                 False        False
# 24      LiH  sto3g                False                 False        False
# 25      H2O  sto3g                False                 False         True
# 26      H2O  sto3g                False                 False        False
# 27      H2O  sto3g                False                 False        False
# 28      H2O  sto3g                False                 False        False
# 29      H2O  sto3g                False                 False        False
# 30      LiH  sto3g                False                  True         True
# 31      H2O  sto3g                False                  True         True
# 32      LiH  sto3g                False                 False         True
# 33      LiH  sto3g                False                 False         True
# 34      H2O  sto3g                False                  True        False
#
#           mapping  qubits  num_paulis  vqe_value  exact_value  \
# 0          parity       4          15  -1.842665    -1.842687
# 1   jordan_wigner       4          15  -1.842687    -1.842687
# 2          parity       6         159  -1.851596    -1.857258
# 3   jordan_wigner       8         185  -1.832113    -1.857258
# 4          parity       8         185  -1.604568    -1.857258
# 5   bravyi_kitaev       4          15  -1.842686    -1.842687
# 6   bravyi_kitaev       8         185  -1.602965    -1.857258
# 7          parity       8         558  -8.873280    -8.874532
# 8          parity       6         231  -0.950255    -1.078084
# 9          parity      10         631  -8.854103    -8.874532
# 10  bravyi_kitaev       6         231  -1.058683    -1.078084
# 11  bravyi_kitaev       8         558  -8.854072    -8.874532
# 12         parity       8         514 -22.421648   -23.544497
# 13         parity      10        1035 -83.259549   -84.206351
# 14  bravyi_kitaev      10        1035 -82.796716   -84.206351
# 15  bravyi_kitaev       8         514 -23.500814   -23.544497
# 16  jordan_wigner      12         551 -23.495240   -23.544497
# 17         parity      12         631  -8.804100    -8.874532
# 18          neven       4          15  -1.821730    -1.842687
# 19          neven       8         185  -1.838184    -1.857258
# 20  bravyi_kitaev      12         631  -8.775878    -8.874532
# 21         parity      12         551 -23.105193   -23.544497
# 22  bravyi_kitaev      12         551 -23.087219   -23.544497
# 23  jordan_wigner      12         631  -8.854050    -8.874532
# 24          neven      12         631  -8.854072    -8.874532
# 25          neven      12         551 -23.498458   -23.544497
# 26         parity      14        1086 -84.156858   -84.206351
# 27  bravyi_kitaev      14        1086 -83.888997   -84.206351
# 28  jordan_wigner      14        1086 -83.855215   -84.206351
# 29          neven      14        1086 -83.552543   -84.206351
# 30  jordan_wigner       6         231  -1.077719    -1.078084
# 31  jordan_wigner       8         514 -22.560908   -23.544497
# 32          neven      10         276  -0.917960    -1.078084
# 33  jordan_wigner      10         276  -0.989154    -1.078084
# 34  jordan_wigner      10        1035 -82.588163   -84.206351
#
#                      name
# 0            4q H2 parity
# 1     4q H2 jordan_wigner
# 2            6q H2 parity
# 3     8q H2 jordan_wigner
# 4            8q H2 parity
# 5     4q H2 bravyi_kitaev
# 6     8q H2 bravyi_kitaev
# 7           8q LiH parity
# 8           6q LiH parity
# 9          10q LiH parity
# 10   6q LiH bravyi_kitaev
# 11   8q LiH bravyi_kitaev
# 12          8q H2O parity
# 13         10q H2O parity
# 14  10q H2O bravyi_kitaev
# 15   8q H2O bravyi_kitaev
# 16  12q H2O jordan_wigner
# 17         12q LiH parity
# 18            4q H2 neven
# 19            8q H2 neven
# 20  12q LiH bravyi_kitaev
# 21         12q H2O parity
# 22  12q H2O bravyi_kitaev
# 23  12q LiH jordan_wigner
# 24          12q LiH neven
# 25          12q H2O neven
# 26         14q H2O parity
# 27  14q H2O bravyi_kitaev
# 28  14q H2O jordan_wigner
# 29          14q H2O neven
# 30   6q LiH jordan_wigner
# 31   8q H2O jordan_wigner
# 32          10q LiH neven
# 33  10q LiH jordan_wigner
# 34  10q H2O jordan_wigner
